# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../data/raw_data.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv("../data/raw_data.csv")
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
# removing the unnamed: 0 col

df = df[['Company', 'TypeName', 'Inches', 'ScreenResolution',
       'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price']]
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # removing the unnamed: 0 col
# ----> 3 df = df[['Company', 'TypeName', 'Inches', 'ScreenResolution',
#       4        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price']]
#       5 df.head()
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
# checking for duplicated rows

df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # checking for duplicated rows
# ----> 3 df.duplicated().sum()
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
catvars = df.select_dtypes(include=['object']).columns
numvars = df.select_dtypes(include = ['int32','int64','float32','float64']).columns

catvars,numvars
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 catvars = df.select_dtypes(include=['object']).columns
#       2 numvars = df.select_dtypes(include = ['int32','int64','float32','float64']).columns
#       4 catvars,numvars
#
# NameError: name 'df' is not defined

# %%
def uniquevals(col):
    print(f'Details of the particular col {col} is : {df[col].unique()}')
    
def valuecounts(col):
    print(f'Valuecounts of the particular col {col} is : {df[col].value_counts()}')
    
    
    
    
for col in df.columns:
    uniquevals(col)
    print("-"*75)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 10
#       4 def valuecounts(col):
#       5     print(f'Valuecounts of the particular col {col} is : {df[col].value_counts()}')
# ---> 10 for col in df.columns:
#      11     uniquevals(col)
#      12     print("-"*75)
#
# NameError: name 'df' is not defined

# %%
'''
so on observation we can see that if we remove "GB" from RAM,i can 
make it as an integer value then after,now same goes with Memory as 
well as Weight,for Weight i can classify it as floating variable
using the str.replace() as shown ↓
'''

df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       1 '''
#       2 so on observation we can see that if we remove "GB" from RAM,i can
#       3 make it as an integer value then after,now same goes with Memory as
#       4 well as Weight,for Weight i can classify it as floating variable
#       5 using the str.replace() as shown ↓
#       6 '''
# ----> 8 df['Ram'] = df['Ram'].str.replace('GB','')
#       9 df['Weight'] = df['Weight'].str.replace('kg','')
#
# NameError: name 'df' is not defined

# %%
# converting from string->integer for ram column

df['Ram'] = df['Ram'].astype('int32')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # converting from string->integer for ram column
# ----> 3 df['Ram'] = df['Ram'].astype('int32')
#
# NameError: name 'df' is not defined

# %%
# converting from string-> float for the weight column

df['Weight'] = df['Weight'].astype('float32')

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # converting from string-> float for the weight column
# ----> 3 df['Weight'] = df['Weight'].astype('float32')
#       5 df.head()
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
# viewing the distribution of the price column
plt.figure(figsize=(4,4))
sn.distplot(df['Price'],color='red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # viewing the distribution of the price column
# ----> 2 plt.figure(figsize=(4,4))
#       3 sn.distplot(df['Price'],color='red')
#
# NameError: name 'plt' is not defined

# %%
## plotting countplots for the categorical variables

def drawplot(col):
    plt.figure(figsize=(5,5))
    sn.countplot(data= df, x = col, palette='plasma')
    plt.xticks(rotation='vertical')
    
toview = ['Company', 'TypeName','Ram','OpSys']
for col in toview:
    drawplot(col)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 10
#       8 toview = ['Company', 'TypeName','Ram','OpSys']
#       9 for col in toview:
# ---> 10     drawplot(col)
#
# Cell In[15], line 4, in drawplot(col)
#       3 def drawplot(col):
# ----> 4     plt.figure(figsize=(5,5))
#       5     sn.countplot(data= df, x = col, palette='plasma')
#       6     plt.xticks(rotation='vertical')
#
# NameError: name 'plt' is not defined

# %%
# average price for each of the laptop brands
# this will say us the insight that as per company the price of the laptop vary


plt.figure(figsize=(5,5))
sn.barplot(x = df['Company'],y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       1 # average price for each of the laptop brands
#       2 # this will say us the insight that as per company the price of the laptop vary
# ----> 5 plt.figure(figsize=(5,5))
#       6 sn.barplot(x = df['Company'],y = df['Price'])
#       7 plt.xticks(rotation = 'vertical')
#
# NameError: name 'plt' is not defined

# %%
## various types of laptops

sn.countplot(data = df, x = 'TypeName',palette='autumn') 
plt.xticks(rotation = 'vertical')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 ## various types of laptops
# ----> 3 sn.countplot(data = df, x = 'TypeName',palette='autumn')
#       4 plt.xticks(rotation = 'vertical')
#
# NameError: name 'sn' is not defined

# %%
# laptop type and variation about the price 

sn.barplot(x = df['TypeName'],y = df['Price'])
plt.xticks(rotation = 'vertical')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # laptop type and variation about the price
# ----> 3 sn.barplot(x = df['TypeName'],y = df['Price'])
#       4 plt.xticks(rotation = 'vertical')
#
# NameError: name 'sn' is not defined

# %%
# variation of inches towards the price

sn.scatterplot(x = df['Inches'],y = df['Price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 # variation of inches towards the price
# ----> 3 sn.scatterplot(x = df['Inches'],y = df['Price'])
#
# NameError: name 'sn' is not defined

# %%
#**For the `Screen Resolution` column we have many types of Screen Resolutions out there as shown `Touch Screen` and `Normal` and `IPS Panel` are the 3 parts on basis of which we can segregate the things**

# %%
df['ScreenResolution'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df['ScreenResolution'].value_counts()
#
# NameError: name 'df' is not defined

# %%
# creating a new col,touchscreen if the value is 1 that laptop is touch screen

df['TouchScreen'] = df['ScreenResolution'].apply(lambda element:1 if 'Touchscreen' in element else 0)

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 # creating a new col,touchscreen if the value is 1 that laptop is touch screen
# ----> 3 df['TouchScreen'] = df['ScreenResolution'].apply(lambda element:1 if 'Touchscreen' in element else 0)
#       5 df.head()
#
# NameError: name 'df' is not defined

# %%
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.sample(5)
#
# NameError: name 'df' is not defined

# %%
sn.countplot(data = df, x = 'TouchScreen' ,palette='plasma')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sn.countplot(data = df, x = 'TouchScreen' ,palette='plasma')
#
# NameError: name 'sn' is not defined

# %%
# touch screen on comparision with price of laptop

sn.barplot(x = df['TouchScreen'],y = df['Price'])
plt.xticks(rotation = 'vertical')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # touch screen on comparision with price of laptop
# ----> 3 sn.barplot(x = df['TouchScreen'],y = df['Price'])
#       4 plt.xticks(rotation = 'vertical')
#
# NameError: name 'sn' is not defined

# %%
# creating a new col named IPS,does the laptop have IPS facility or not

df['IPS'] = df['ScreenResolution'].apply(lambda element:1 if "IPS" in element else 0)
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 # creating a new col named IPS,does the laptop have IPS facility or not
# ----> 3 df['IPS'] = df['ScreenResolution'].apply(lambda element:1 if "IPS" in element else 0)
#       4 df.sample(5)
#
# NameError: name 'df' is not defined

# %%
sn.countplot(data= df, x = "IPS",palette='plasma')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sn.countplot(data= df, x = "IPS",palette='plasma')
#
# NameError: name 'sn' is not defined

# %%
# price variation with respect to the IPS col

sn.barplot(x = df['TouchScreen'],y = df['Price'])
plt.xticks(rotation = 'vertical')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 # price variation with respect to the IPS col
# ----> 3 sn.barplot(x = df['TouchScreen'],y = df['Price'])
#       4 plt.xticks(rotation = 'vertical')
#
# NameError: name 'sn' is not defined

# %%
# we will split the text at the "x" letter and seperate the 2 parts
# from this we can observe that one of the col is Y res we need to do
# some feature engineering on the X res col

splitdf = df['ScreenResolution'].str.split('x',n = 1,expand=True)
splitdf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 5
#       1 # we will split the text at the "x" letter and seperate the 2 parts
#       2 # from this we can observe that one of the col is Y res we need to do
#       3 # some feature engineering on the X res col
# ----> 5 splitdf = df['ScreenResolution'].str.split('x',n = 1,expand=True)
#       6 splitdf.head()
#
# NameError: name 'df' is not defined

# %%
splitdf = df['ScreenResolution'].str.split('x',n = 1,expand=True)

df['X_res'] = splitdf[0]
df['Y_res'] = splitdf[1]
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 splitdf = df['ScreenResolution'].str.split('x',n = 1,expand=True)
#       3 df['X_res'] = splitdf[0]
#       4 df['Y_res'] = splitdf[1]
#
# NameError: name 'df' is not defined

# %%
'''
So basically from that whole text of the X_res col,we need to 
extract the digits from it,but the problem is the numbers are scattered 
in some cases,that is the reason why i am using regex,if we use this
we will exactly get the numbers which we are looking for!,
so firstly replace all the "," with "" and then find all numbers
from that string as "\d+\.?\d+",\d means that integer number and \.? 
all the numbers which come after an number and \d+ the string must end with number


'''


df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\HP\AppData\Local\Temp\ipykernel_13168\3865861558.py:1: SyntaxWarning: invalid escape sequence '\d'
#   '''
# C:\Users\HP\AppData\Local\Temp\ipykernel_13168\3865861558.py:1: SyntaxWarning: invalid escape sequence '\d'
#   '''
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 14
#       1 '''
#       2 So basically from that whole text of the X_res col,we need to
#       3 extract the digits from it,but the problem is the numbers are scattered
#    (...)     10
#      11 '''
# ---> 14 df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
#      16 df.head()
#
# NameError: name 'df' is not defined

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df['X_res'] = df['X_res'].astype('int')
#       2 df['Y_res'] = df['Y_res'].astype('int')
#       3 df.info()
#
# NameError: name 'df' is not defined

# %%
# Select only the numeric columns from the DataFrame
numeric_df = df.select_dtypes(include=['number'])

# Create the heatmap for the numeric columns
plt.figure(figsize=(10,7))
sn.heatmap(numeric_df.corr(), annot=True, cmap='plasma')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Select only the numeric columns from the DataFrame
# ----> 2 numeric_df = df.select_dtypes(include=['number'])
#       4 # Create the heatmap for the numeric columns
#       5 plt.figure(figsize=(10,7))
#
# NameError: name 'df' is not defined

# %%
numeric_df.corr()['Price']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 numeric_df.corr()['Price']
#
# NameError: name 'numeric_df' is not defined

# %%
df['PPI'] = (((df['X_res']**2+df['Y_res']**2))**0.5/df['Inches']).astype('float')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df['PPI'] = (((df['X_res']**2+df['Y_res']**2))**0.5/df['Inches']).astype('float')
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
numeric_df = df.select_dtypes(include=['number'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 numeric_df = df.select_dtypes(include=['number'])
#
# NameError: name 'df' is not defined

# %%
numeric_df.corr()['Price']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 numeric_df.corr()['Price']
#
# NameError: name 'numeric_df' is not defined

# %%
df.drop(columns=['ScreenResolution','Inches','X_res','Y_res'],inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.drop(columns=['ScreenResolution','Inches','X_res','Y_res'],inplace=True)
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
df['Cpu'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df['Cpu'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df['CPU_name'] = df['Cpu'].apply(lambda text:" ".join(text.split()[:3]))
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df['CPU_name'] = df['Cpu'].apply(lambda text:" ".join(text.split()[:3]))
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
df['CPU_name'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df['CPU_name'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df['CPU_name'] = df['Cpu'].apply(lambda text:" ".join(text.split()[:3]))
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df['CPU_name'] = df['Cpu'].apply(lambda text:" ".join(text.split()[:3]))
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
# Replace values in 'CPU_name' column based on conditions
def update_cpu_name(cpu):
    if 'Intel' in cpu:
        if 'Core i7' in cpu:
            return 'Intel Core i7'
        elif 'Core i5' in cpu:
            return 'Intel Core i5'
        elif 'Core i3' in cpu:
            return 'Intel Core i3'
        else:
            return 'Intel Processor'  # For other Intel processors
    elif 'AMD' in cpu:
        return 'AMD Processor'  # For all AMD processors
    else:
        return cpu  # For any other processors that don't match

# Apply the function to the 'CPU_name' column
df['CPU_name1'] = df['CPU_name'].apply(update_cpu_name)

# Display the updated DataFrame
print(df['CPU_name1'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 18
#      15         return cpu  # For any other processors that don't match
#      17 # Apply the function to the 'CPU_name' column
# ---> 18 df['CPU_name1'] = df['CPU_name'].apply(update_cpu_name)
#      20 # Display the updated DataFrame
#      21 print(df['CPU_name1'].value_counts())
#
# NameError: name 'df' is not defined

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
sn.countplot(data = df, x ='CPU_name1', palette='plasma')
plt.xticks(rotation = 'vertical')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 sn.countplot(data = df, x ='CPU_name1', palette='plasma')
#       2 plt.xticks(rotation = 'vertical')
#
# NameError: name 'sn' is not defined

# %%
# Plotting price vs CPU_name variation
sn.barplot(x='CPU_name1', y='Price', data=df)

# Rotate the x-axis labels for better readability
plt.xticks(rotation='vertical')

# Optionally, add labels for clarity
plt.xlabel('CPU Name1')
plt.ylabel('Price')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 # Plotting price vs CPU_name variation
# ----> 2 sn.barplot(x='CPU_name1', y='Price', data=df)
#       4 # Rotate the x-axis labels for better readability
#       5 plt.xticks(rotation='vertical')
#
# NameError: name 'sn' is not defined

# %%
## dropping the cpu column

df.drop(columns=['Cpu'],inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 3
#       1 ## dropping the cpu column
# ----> 3 df.drop(columns=['Cpu'],inplace=True)
#       4 df.head()
#
# NameError: name 'df' is not defined

# %%
sn.countplot(data = df , x = 'Ram',palette='autumn')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 sn.countplot(data = df , x = 'Ram',palette='autumn')
#
# NameError: name 'sn' is not defined

# %%
sn.barplot(x = df['Ram'],y = df['Price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 sn.barplot(x = df['Ram'],y = df['Price'])
#
# NameError: name 'sn' is not defined

# %%
df['Memory'].iloc[:1][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df['Memory'].iloc[:1][0]
#
# NameError: name 'df' is not defined

# %%
df['Memory'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df['Memory'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0','',regex = True)

# replace the GB word with " "

df['Memory'] = df['Memory'].str.replace('GB','')

# replace the TB word with "000"

df['Memory'] = df['Memory'].str.replace('TB','000')

# split the word accross the "+" character

newdf = df['Memory'].str.split("+",n = 1,expand = True)

newdf
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\HP\AppData\Local\Temp\ipykernel_13168\3372626095.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df['Memory'] = df['Memory'].astype(str).replace('\.0','',regex = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_13168\3372626095.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df['Memory'] = df['Memory'].astype(str).replace('\.0','',regex = True)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df['Memory'] = df['Memory'].astype(str).replace('\.0','',regex = True)
#       3 # replace the GB word with " "
#       5 df['Memory'] = df['Memory'].str.replace('GB','')
#
# NameError: name 'df' is not defined

# %%
df['first'] = newdf[0]
df['first'] = df['first'].str.strip()
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df['first'] = newdf[0]
#       2 df['first'] = df['first'].str.strip()
#       3 df.head()
#
# NameError: name 'newdf' is not defined

# %%
def applychanges(value):
    
    df['Layer1'+value] = df['first'].apply(lambda x:1 if value in x else 0)
    
    
listtoapply = ['HDD','SSD','Hybrid','FlashStorage']    
for value in listtoapply:
    applychanges(value)
    
    
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 8
#       6 listtoapply = ['HDD','SSD','Hybrid','FlashStorage']
#       7 for value in listtoapply:
# ----> 8     applychanges(value)
#      11 df.head()
#
# Cell In[54], line 3, in applychanges(value)
#       1 def applychanges(value):
# ----> 3     df['Layer1'+value] = df['first'].apply(lambda x:1 if value in x else 0)
#
# NameError: name 'df' is not defined

# %%
# Remove all non-digit characters and keep only the numbers
df['first'] = df['first'].str.replace(r'\D', '', regex=True)

# Convert to numeric values if needed (optional)
df['first'] = pd.to_numeric(df['first'], errors='coerce')

# Check the value counts after the transformation
print(df['first'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 # Remove all non-digit characters and keep only the numbers
# ----> 2 df['first'] = df['first'].str.replace(r'\D', '', regex=True)
#       4 # Convert to numeric values if needed (optional)
#       5 df['first'] = pd.to_numeric(df['first'], errors='coerce')
#
# NameError: name 'df' is not defined

# %%
df['Second'] = newdf[1]
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df['Second'] = newdf[1]
#       2 df.head()
#
# NameError: name 'newdf' is not defined

# %%
def applychanges1(value):
    
    df['Layer2'+value] = df['Second'].apply(lambda x:1 if value in x else 0)
    
    
listtoapply1 = ['HDD','SSD','Hybrid','FlashStorage']
df['Second'] = df['Second'].fillna("0")
for value in listtoapply1:
    applychanges1(value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 7
#       3     df['Layer2'+value] = df['Second'].apply(lambda x:1 if value in x else 0)
#       6 listtoapply1 = ['HDD','SSD','Hybrid','FlashStorage']
# ----> 7 df['Second'] = df['Second'].fillna("0")
#       8 for value in listtoapply1:
#       9     applychanges1(value)
#
# NameError: name 'df' is not defined

# %%
# Remove all non-digit characters from the 'Second' column
df['Second'] = df['Second'].str.replace(r'\D', '', regex=True)

# Check the value counts after the transformation
print(df['Second'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 2
#       1 # Remove all non-digit characters from the 'Second' column
# ----> 2 df['Second'] = df['Second'].str.replace(r'\D', '', regex=True)
#       4 # Check the value counts after the transformation
#       5 print(df['Second'].value_counts())
#
# NameError: name 'df' is not defined

# %%
df['first'] = df['first'].astype('int')
df['Second'] = df['Second'].astype('int')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df['first'] = df['first'].astype('int')
#       2 df['Second'] = df['Second'].astype('int')
#       3 df.head()
#
# NameError: name 'df' is not defined

# %%
df["HDD"]=(df["first"]*df["Layer1HDD"]+df["Second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["Second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["Second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1FlashStorage"]+df["Second"]*df["Layer2FlashStorage"])


## dropping of uncessary columns

df.drop(columns=['first', 'Second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1FlashStorage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2FlashStorage'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df["HDD"]=(df["first"]*df["Layer1HDD"]+df["Second"]*df["Layer2HDD"])
#       2 df["SSD"]=(df["first"]*df["Layer1SSD"]+df["Second"]*df["Layer2SSD"])
#       3 df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["Second"]*df["Layer2Hybrid"])
#
# NameError: name 'df' is not defined

# %%
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df.sample(5)
#
# NameError: name 'df' is not defined

# %%
df.drop(columns=['Memory'],inplace=True)
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df.drop(columns=['Memory'],inplace=True)
#       2 df.sample(5)
#
# NameError: name 'df' is not defined

# %%
# Select only the numeric columns from the DataFrame
numeric_df = df.select_dtypes(include=['number'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 2
#       1 # Select only the numeric columns from the DataFrame
# ----> 2 numeric_df = df.select_dtypes(include=['number'])
#
# NameError: name 'df' is not defined

# %%
numeric_df.corr()['Price']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 numeric_df.corr()['Price']
#
# NameError: name 'numeric_df' is not defined

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df.drop(columns = ['Hybrid','Flash_Storage'],inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df.drop(columns = ['Hybrid','Flash_Storage'],inplace=True)
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
##### Analysis on GPU

# %%
df['Gpu'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df['Gpu'].value_counts()
#
# NameError: name 'df' is not defined

# %%
##### **Here as we are having less data regarding the laptops,its better that we focus on `GPU brands` instead focusing on the values which are present there beside them,we will focus on the `brands`**

# %%
# this is what we will be doing,extracting the brands 
a = df['Gpu'].iloc[1]
print(a.split()[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 2
#       1 # this is what we will be doing,extracting the brands
# ----> 2 a = df['Gpu'].iloc[1]
#       3 print(a.split()[0])
#
# NameError: name 'df' is not defined

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])
sn.countplot(data = df , x= 'Gpu brand',palette='plasma')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])
#       2 sn.countplot(data = df , x= 'Gpu brand',palette='plasma')
#
# NameError: name 'df' is not defined

# %%
# removing the "ARM" tuple

df = df[df['Gpu brand']!='ARM']
sn.countplot(data = df, x = 'Gpu brand',palette='plasma')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 3
#       1 # removing the "ARM" tuple
# ----> 3 df = df[df['Gpu brand']!='ARM']
#       4 sn.countplot(data = df, x = 'Gpu brand',palette='plasma')
#
# NameError: name 'df' is not defined

# %%
# price-GPU analysis,i used np.median inorder to check if there is any
# inpact of outlier or not


sn.barplot(x= df['Gpu brand'],y =df['Price'],estimator=np.median)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 5
#       1 # price-GPU analysis,i used np.median inorder to check if there is any
#       2 # inpact of outlier or not
# ----> 5 sn.barplot(x= df['Gpu brand'],y =df['Price'],estimator=np.median)
#
# NameError: name 'sn' is not defined

# %%
df = df.drop(columns=['Gpu'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 df = df.drop(columns=['Gpu'])
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
#### Operating System analysis

# %%
df['OpSys'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df['OpSys'].value_counts()
#
# NameError: name 'df' is not defined

# %%
sn.barplot(x= df['OpSys'],y= df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 sn.barplot(x= df['OpSys'],y= df['Price'])
#       2 plt.xticks(rotation = 'vertical')
#       3 plt.show()
#
# NameError: name 'sn' is not defined

# %%
df['OpSys'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 df['OpSys'].unique()
#
# NameError: name 'df' is not defined

# %%
# club {Windows 10,Windows 7,Windows 7 S}-->Windows
# club {macOS,mac OS X}--> mac
# else return Others

def setcategory(text):
    
    if text=='Windows 10' or text=='Windows 7' or text=='Windows 10 S':
        return 'Windows'
    
    elif text=='Mac OS X' or text=='macOS':
        return 'Mac'
    
    else:
        return 'Other'
    
    
df['OpSys'] = df['OpSys'].apply(lambda x:setcategory(x))


df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 17
#      13     else:
#      14         return 'Other'
# ---> 17 df['OpSys'] = df['OpSys'].apply(lambda x:setcategory(x))
#      20 df.head()
#
# NameError: name 'df' is not defined

# %%
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df.sample(5)
#
# NameError: name 'df' is not defined

# %%
sn.countplot(data = df, x= df['OpSys'],palette='plasma')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 sn.countplot(data = df, x= df['OpSys'],palette='plasma')
#
# NameError: name 'sn' is not defined

# %%
sn.barplot(x = df['OpSys'],y = df['Price'])
plt.xticks(rotation = 'vertical')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 sn.barplot(x = df['OpSys'],y = df['Price'])
#       2 plt.xticks(rotation = 'vertical')
#
# NameError: name 'sn' is not defined

# %%
sn.distplot(df['Weight'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 sn.distplot(df['Weight'])
#
# NameError: name 'sn' is not defined

# %%
sn.scatterplot(x= df['Weight'],y=df['Price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 sn.scatterplot(x= df['Weight'],y=df['Price'])
#
# NameError: name 'sn' is not defined

# %%
#### Price Analysis

# %%
sn.distplot(df['Price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 sn.distplot(df['Price'])
#
# NameError: name 'sn' is not defined

# %%
# so if we apply np.log to the Price col we get a gaussian distibution

sn.distplot(np.log(df['Price']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 3
#       1 # so if we apply np.log to the Price col we get a gaussian distibution
# ----> 3 sn.distplot(np.log(df['Price']))
#
# NameError: name 'sn' is not defined

# %%
# Select only the numeric columns from the DataFrame
numeric_df = df.select_dtypes(include=['number'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 2
#       1 # Select only the numeric columns from the DataFrame
# ----> 2 numeric_df = df.select_dtypes(include=['number'])
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(10,5))
sn.heatmap(numeric_df.corr(),annot=True,cmap='plasma')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 plt.figure(figsize=(10,5))
#       2 sn.heatmap(numeric_df.corr(),annot=True,cmap='plasma')
#
# NameError: name 'plt' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
# Output CSV file to main data directory
file_path = "../data/clean_data.csv"
df.to_csv(file_path, index=False)
print(f"✅ Loaded {df.shape[0]} records and saved to {file_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 3
#       1 # Output CSV file to main data directory
#       2 file_path = "../data/clean_data.csv"
# ----> 3 df.to_csv(file_path, index=False)
#       4 print(f"✅ Loaded {df.shape[0]} records and saved to {file_path}")
#
# NameError: name 'df' is not defined
